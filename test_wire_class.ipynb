# %%
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from wire import Wire
import numpy as np

# %%
wire = Wire("prototype_double_cos_coil/coil1/wires/wire10.txt")

# %%
wire.points.shape
# Out:
# (3, 436)

# %%
dx = []
dy = []
dz = []
for i in np.arange(wire.points.shape[1])[::20]:
    d_vec = wire.interp.derivative_direction(i)
    dx.append(d_vec[0])
    dy.append(d_vec[1])
    dz.append(d_vec[2])

# %%
# %matplotlib notebook
fig = plt.figure(figsize=(5,5))
ax = plt.axes(projection="3d")
ax.plot(wire.points[0], wire.points[1], wire.points[2], 'o-', markersize=1, c='k')
ax.quiver(wire.points[0][::20], wire.points[1][::20], wire.points[2][::20], dx, dy, dz, length=0.01)
range = max(wire.points[0]) - min(wire.points[0])
ax.set_ylim(-range/2, range/2)
ax.set_zlim(-range/2, range/2)
ax.set_xlabel("x")
ax.set_ylabel("y")
# Out:
# <img src="data:image/png;base64,..." width="500">
# Text(0.5, 0, 'y')

# %%
wire_sampled = wire.get_resampled_wire(resolution=.001)

# %%
wire_sampled.points.shape
# Out:
# (3, 618)

# %%
# %matplotlib notebook
fig = plt.figure(figsize=(5,5))
ax = plt.axes(projection="3d")
ax.plot(wire_sampled.points[0], wire_sampled.points[1], wire_sampled.points[2], 'o-', markersize=1)
range = max(wire_sampled.points[0]) - min(wire_sampled.points[0])
ax.set_ylim(-range/2, range/2)
ax.set_zlim(-range/2, range/2)
# Out:
# <img src="data:image/png;base64,..." width="500">
# (-0.1498982245238587, 0.1498982245238587)

# %%
import numpy as np

# %%
x = np.arange(21)
x = np.reshape(x, (7,3))
x

# %%
wire.points[:,0]
